# %%
#!pip install twitterscraper
# !pip install lxml

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import seaborn as sns
import pymysql
import requests
from bs4 import BeautifulSoup
import datetime
import json
import re


mpl.rcParams['axes.unicode_minus'] = False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

plt.rcParams['figure.figsize'] = (15,5)
plt.rcParams['font.size'] = 14

# %%
team_key = {'두산':'OB', '키움':'WO', 'SK':'SK', 'LG':'LG', 'NC':'NC', 
         'KT':'KT', 'KIA':'HT', '삼성':'SS', '한화':'HH', '롯데':'LT'}
team_temp = ['LT', 'OB', 'LG', 'WO', 'SK', 'HH']#, 'NC', 'KT', 'HT', 'SS']

# %%
#team = 'SK'
date = ''
def news_search_2019(team, date, df1) :
    url = 'https://sports.news.naver.com/kbaseball/news/list.nhn?\
    isphoto=N&type=team&team={}&date={}'.format(team, date)
    res = requests.get(url).json()
    team_news_list = res['list']
    # bs = BeautifulSoup(res.text,'html.parser')

    # def parse_content(url):
    def parse_content(url):
        res = requests.get(url)
        bs = BeautifulSoup(res.text,'html.parser')
        content = bs.select('#newsEndContents')[0].text.strip()
        content = content.replace('/','')
        content = re.sub('\[(.*?)\]', '', content)
        content = re.sub('[a-zA-Z0-9]+@[a-zA-Z0-9]+([\.co\.kr]|[\.com])+', '', content)
        content = re.sub('[현]+(.*?)[다.]+', '', content)
        return content

    # https://sports.news.naver.com/news.nhn?oid=425&aid=0000109083
    news_df = []
    for news in team_news_list:
        news_dic = {}
        content_url = 'https://sports.news.naver.com/news.nhn?oid={}&aid={}'.format(news['oid'],news['aid'])
        news_dic['title'] = news['title']
        news_dic['date'] = news['datetime']
        news_dic['content'] = parse_content(content_url)
        news_df.append(news_dic)
    #     news_df.append(pd.DataFrame(data=news_dic))
    for i in range(len(news_df)):
        news_df[i]['content'] = news_df[i]['content'].split('\n')[0].split('▶')[0].split('\t')[0]
        for w in ['무단전재 및 재배포 금지', '재배포 금지', '재배포금지', 'ⓒGettyimages']:
            if w in news_df[i]['content']:
                news_df[i]['content'] = news_df[i]['content'].replace(w, '')
    df2 = pd.DataFrame(news_df)
    return(df2)

for x in team_temp:
    df1 = pd.DataFrame()
    for i in pd.date_range(start="2018-03-24",end="2018-09-30"):
        i = i.strftime('%Y%m%d')
        print(i[2:],end=' ')
        try:
            temp = news_search_2019(x, str(i), df1)
        except:
            continue
        df1 = pd.concat([df1, temp])
    df1.reset_index(drop=True)
    df1.to_excel('./kbo_news/{}_2018.xlsx'.format(x))
# Out:
# 180324 180325 180326 180327 180328 180329 180330 180331 180401 180402 180403 180404 180405 180406 180407 180408 180409 180410 180411 180412 180413 180414 180415 180416 180417 180418 180419 180420 180421 180422 180423 180424 180425 180426 180427 180428 180429 180430 180501 180502 180503 180504 180505 180506 180507 180508 180509 180510 180511 180512 180513 180514 180515 180516 180517 180518 180519 180520 180521 180522 180523 180524 180525 180526 180527 180528 180529 180530 180531 180601 180602 180603 180604 180605 180606 180607 180608 180609 180610 180611 180612 180613 180614 180615 180616 180617 180618